# %%
from src.get_statement import *
from src. get_announcement import *
from bs4 import BeautifulSoup
get_statement()
# Out:
# PDF kaydedildi: document_output/2024-03-11/CANTE_1256847.pdf
# PDF kaydedildi: document_output/2024-03-11/CCOLA_1256798.pdf
# PDF kaydedildi: document_output/2024-03-11/EREGL_1256526.pdf
# PDF kaydedildi: document_output/2024-03-11/ENERY_1256503.pdf
# PDF kaydedildi: document_output/2024-03-11/AHGAZ_1256496.pdf
# PDF kaydedildi: document_output/2024-03-11/ENKAI_1256466.pdf
# PDF kaydedildi: document_output/2024-03-11/ENKAI_1256463.pdf
# PDF kaydedildi: document_output/2024-03-11/ENJSA_1256313.pdf
# Files reading
#     disc_index company_name                                               text
# 0      1256919        CWENE  Şirketimiz ile yurt içerisinde yerleşik bir mü...
# 1      1256691        AKBNK  İlgi:06.03.2024 tarihli Özel Durum Açıklaması....
# 2      1256638        ISMEN  İhraççısı ve piyasa yapıcısı olduğumuz İş Yatı...
# 3      1256570        ASTOR  Şirketimiz Astor Enerji A.Ş. ("Astor"), pay sa...
# ...
